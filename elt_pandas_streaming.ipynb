# %%
import requests
import json
import pandas as pd
import numpy as np
import psycopg2
from psycopg2.extras import execute_values

# %%
##insert movies##
url='https://api.themoviedb.org/3/movie/top_rated?api_key=76f3ff736cde9a95c8dde41456f28cda&language=en-US&page={}'
    
response = requests.get(url)
if response.status_code==200:
      
            movies = pd.DataFrame(response.json()["results"])[['id','original_title','release_date','genre_ids','vote_average','vote_count']]
            
        
for i in range(1, 4):
             response = requests.get(url)
             temp_df = pd.DataFrame(response.json()["results"])[['id','original_title','release_date','genre_ids','vote_average','vote_count']]
             movies.append(temp_df, ignore_index=False)
        
        
             #print(movies) ##Visualizo los datos
             
## rename it original_title as name
# Out:
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\256939419.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movies.append(temp_df, ignore_index=False)
#         id                                 original_title release_date  \
# 0      238                                  The Godfather   1972-03-14
# 1      278                       The Shawshank Redemption   1994-09-23
# 2   772071                               Cuando Sea Joven   2022-09-14
# 3      240                          The Godfather Part II   1974-12-20
# 4    19404                   दिलवाले दुल्हनिया ले जायेंगे   1995-10-19
# 5      424                               Schindler's List   1993-12-15
# 6      129                                       千と千尋の神隠し   2001-07-20
# 7      389                                   12 Angry Men   1957-04-10
# 8   372058                                          君の名は。   2016-08-26
# 9   496243                                            기생충   2019-05-30
# 10     155                                The Dark Knight   2008-07-14
# 11     497                                 The Green Mile   1999-12-10
# 12     680                                   Pulp Fiction   1994-09-10
# 13     429                Il buono, il brutto, il cattivo   1966-12-23
# 14      13                                   Forrest Gump   1994-06-23
# 15  372754                                            同級生   2016-02-20
# 16     122  The Lord of the Rings: The Return of the King   2003-12-01
# 17     769                                     GoodFellas   1990-09-12
# 18  704264                      Primal: Tales of Savagery   2019-11-21
# 19  995133       The Boy, the Mole, the Fox and the Horse   2022-12-25
#
#               genre_ids  vote_average  vote_count
# 0              [18, 80]           8.7       17944
# 1              [18, 80]           8.7       23783
# 2              [35, 14]           8.6         226
# 3              [18, 80]           8.6       10831
# 4       [35, 18, 10749]           8.6        4131
# 5       [18, 36, 10752]           8.6       14068
# 6       [16, 10751, 14]           8.5       14302
# 7                  [18]           8.5        7273
# 8       [10749, 16, 18]           8.5        9840
# 9          [35, 53, 18]           8.5       15734
# 10     [18, 28, 80, 53]           8.5       29719
# 11         [14, 18, 80]           8.5       15406
# 12             [53, 80]           8.5       25179
# 13                 [37]           8.5        7396
# 14      [35, 18, 10749]           8.5       24664
# 15          [10749, 16]           8.5         304
# 16         [12, 14, 28]           8.5       21594
# 17             [18, 80]           8.5       11256
# 18     [28, 12, 16, 18]           8.5         263
# 19  [16, 10751, 12, 14]           8.5         323
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\256939419.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movies.append(temp_df, ignore_index=False)
#         id                                 original_title release_date  \
# 0      238                                  The Godfather   1972-03-14
# 1      278                       The Shawshank Redemption   1994-09-23
# 2   772071                               Cuando Sea Joven   2022-09-14
# 3      240                          The Godfather Part II   1974-12-20
# 4    19404                   दिलवाले दुल्हनिया ले जायेंगे   1995-10-19
# 5      424                               Schindler's List   1993-12-15
# 6      129                                       千と千尋の神隠し   2001-07-20
# 7      389                                   12 Angry Men   1957-04-10
# 8   372058                                          君の名は。   2016-08-26
# 9   496243                                            기생충   2019-05-30
# 10     155                                The Dark Knight   2008-07-14
# 11     497                                 The Green Mile   1999-12-10
# 12     680                                   Pulp Fiction   1994-09-10
# 13     429                Il buono, il brutto, il cattivo   1966-12-23
# 14      13                                   Forrest Gump   1994-06-23
# 15  372754                                            同級生   2016-02-20
# 16     122  The Lord of the Rings: The Return of the King   2003-12-01
# 17     769                                     GoodFellas   1990-09-12
# 18  704264                      Primal: Tales of Savagery   2019-11-21
# 19  995133       The Boy, the Mole, the Fox and the Horse   2022-12-25
#
#               genre_ids  vote_average  vote_count
# 0              [18, 80]           8.7       17944
# 1              [18, 80]           8.7       23783
# 2              [35, 14]           8.6         226
# 3              [18, 80]           8.6       10831
# 4       [35, 18, 10749]           8.6        4131
# 5       [18, 36, 10752]           8.6       14068
# 6       [16, 10751, 14]           8.5       14302
# 7                  [18]           8.5        7273
# 8       [10749, 16, 18]           8.5        9840
# 9          [35, 53, 18]           8.5       15734
# 10     [18, 28, 80, 53]           8.5       29719
# 11         [14, 18, 80]           8.5       15406
# 12             [53, 80]           8.5       25179
# 13                 [37]           8.5        7396
# 14      [35, 18, 10749]           8.5       24664
# 15          [10749, 16]           8.5         304
# 16         [12, 14, 28]           8.5       21594
# 17             [18, 80]           8.5       11256
# 18     [28, 12, 16, 18]           8.5         263
# 19  [16, 10751, 12, 14]           8.5         323
#         id                                 original_title release_date  \
# 0      238                                  The Godfather   1972-03-14
# 1      278                       The Shawshank Redemption   1994-09-23
# 2   772071                               Cuando Sea Joven   2022-09-14
# 3      240                          The Godfather Part II   1974-12-20
# 4    19404                   दिलवाले दुल्हनिया ले जायेंगे   1995-10-19
# 5      424                               Schindler's List   1993-12-15
# 6      129                                       千と千尋の神隠し   2001-07-20
# 7      389                                   12 Angry Men   1957-04-10
# 8   372058                                          君の名は。   2016-08-26
# 9   496243                                            기생충   2019-05-30
# 10     155                                The Dark Knight   2008-07-14
# 11     497                                 The Green Mile   1999-12-10
# 12     680                                   Pulp Fiction   1994-09-10
# 13     429                Il buono, il brutto, il cattivo   1966-12-23
# 14      13                                   Forrest Gump   1994-06-23
# 15  372754                                            同級生   2016-02-20
# 16     122  The Lord of the Rings: The Return of the King   2003-12-01
# 17     769                                     GoodFellas   1990-09-12
# 18  704264                      Primal: Tales of Savagery   2019-11-21
# 19  995133       The Boy, the Mole, the Fox and the Horse   2022-12-25
#
#               genre_ids  vote_average  vote_count
# 0              [18, 80]           8.7       17944
# 1              [18, 80]           8.7       23783
# 2              [35, 14]           8.6         226
# 3              [18, 80]           8.6       10831
# 4       [35, 18, 10749]           8.6        4131
# 5       [18, 36, 10752]           8.6       14068
# 6       [16, 10751, 14]           8.5       14302
# 7                  [18]           8.5        7273
# 8       [10749, 16, 18]           8.5        9840
# 9          [35, 53, 18]           8.5       15734
# 10     [18, 28, 80, 53]           8.5       29719
# 11         [14, 18, 80]           8.5       15406
# 12             [53, 80]           8.5       25179
# 13                 [37]           8.5        7396
# 14      [35, 18, 10749]           8.5       24664
# 15          [10749, 16]           8.5         304
# 16         [12, 14, 28]           8.5       21594
# 17             [18, 80]           8.5       11256
# 18     [28, 12, 16, 18]           8.5         263
# 19  [16, 10751, 12, 14]           8.5         323
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\256939419.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   movies.append(temp_df, ignore_index=False)

# %%
#convierto el index como columna del df movies
movies['index'] = movies.index

# %%
##convierto el campo genre_ids a lista y completo el largo de la sublista##
genre_ids=movies['genre_ids'].tolist()

tamanio=len (genre_ids)
for i in range(tamanio):
    longitud = len(genre_ids[i])
   # print(longitud)
    while longitud<5:
        genre_ids[i].append(0)
       # print(genre_ids[i])
        longitud+=1
    #print(longitud)

#print(genre_ids)

# %%
#convierto la lista genre_ids a dataframe##
df_genre_ids = pd.DataFrame(genre_ids)
#convierto el index como columna
df_genre_ids['index'] = df_genre_ids.index
print(df_genre_ids)
# Out:
#         0      1      2   3  4  index
# 0      18     80      0   0  0      0
# 1      18     80      0   0  0      1
# 2      35     14      0   0  0      2
# 3      18     80      0   0  0      3
# 4      35     18  10749   0  0      4
# 5      18     36  10752   0  0      5
# 6      16  10751     14   0  0      6
# 7      18      0      0   0  0      7
# 8   10749     16     18   0  0      8
# 9      35     53     18   0  0      9
# 10     18     28     80  53  0     10
# 11     14     18     80   0  0     11
# 12     53     80      0   0  0     12
# 13     37      0      0   0  0     13
# 14     35     18  10749   0  0     14
# 15  10749     16      0   0  0     15
# 16     12     14     28   0  0     16
# 17     18     80      0   0  0     17
# 18     28     12     16  18  0     18
# 19     16  10751     12  14  0     19

# %%
#Uno df movies con df idf_genre_ids por el index
peliculas=pd.merge(movies,df_genre_ids,on='index',how='left')
#peliculas

# %%
## renombro columnas en df peliculas##
peliculas.rename(columns = {'original_title':'nombre','release_date':'fecha_lanzamiento','genre_ids':'id_genero','vote_average':'voto_prom','vote_count':'voto_cant',0:'G0',1:'G1',2:'G2',3:'G3',4:'G4'}, inplace = True)

#creo y completo la columna tipo_streaming
peliculas["tipo_streaming"] = np.nan
peliculas["tipo_streaming"].fillna("peliculas", inplace = True)
#peliculas
# Out:
#         id                                         nombre fecha_lanzamiento  \
# 0      238                                  The Godfather        1972-03-14
# 1      278                       The Shawshank Redemption        1994-09-23
# 2   772071                               Cuando Sea Joven        2022-09-14
# 3      240                          The Godfather Part II        1974-12-20
# 4    19404                   दिलवाले दुल्हनिया ले जायेंगे        1995-10-19
# 5      424                               Schindler's List        1993-12-15
# 6      129                                       千と千尋の神隠し        2001-07-20
# 7      389                                   12 Angry Men        1957-04-10
# 8   372058                                          君の名は。        2016-08-26
# 9   496243                                            기생충        2019-05-30
# 10     155                                The Dark Knight        2008-07-14
# 11     497                                 The Green Mile        1999-12-10
# 12     680                                   Pulp Fiction        1994-09-10
# 13     429                Il buono, il brutto, il cattivo        1966-12-23
# 14      13                                   Forrest Gump        1994-06-23
# 15  372754                                            同級生        2016-02-20
# 16     122  The Lord of the Rings: The Return of the King        2003-12-01
# 17     769                                     GoodFellas        1990-09-12
# 18  704264                      Primal: Tales of Savagery        2019-11-21
# 19  995133       The Boy, the Mole, the Fox and the Horse        2022-12-25
#
#                  id_genero  voto_prom  voto_cant  index     G0     G1     G2  \
# 0        [18, 80, 0, 0, 0]        8.7      17944      0     18     80      0
# 1        [18, 80, 0, 0, 0]        8.7      23783      1     18     80      0
# 2        [35, 14, 0, 0, 0]        8.6        226      2     35     14      0
# 3        [18, 80, 0, 0, 0]        8.6      10831      3     18     80      0
# 4    [35, 18, 10749, 0, 0]        8.6       4131      4     35     18  10749
# 5    [18, 36, 10752, 0, 0]        8.6      14068      5     18     36  10752
# 6    [16, 10751, 14, 0, 0]        8.5      14302      6     16  10751     14
# 7         [18, 0, 0, 0, 0]        8.5       7273      7     18      0      0
# 8    [10749, 16, 18, 0, 0]        8.5       9840      8  10749     16     18
# 9       [35, 53, 18, 0, 0]        8.5      15734      9     35     53     18
# 10     [18, 28, 80, 53, 0]        8.5      29719     10     18     28     80
# 11      [14, 18, 80, 0, 0]        8.5      15406     11     14     18     80
# 12       [53, 80, 0, 0, 0]        8.5      25179     12     53     80      0
# 13        [37, 0, 0, 0, 0]        8.5       7396     13     37      0      0
# 14   [35, 18, 10749, 0, 0]        8.5      24664     14     35     18  10749
# 15    [10749, 16, 0, 0, 0]        8.5        304     15  10749     16      0
# 16      [12, 14, 28, 0, 0]        8.5      21594     16     12     14     28
# 17       [18, 80, 0, 0, 0]        8.5      11256     17     18     80      0
# 18     [28, 12, 16, 18, 0]        8.5        263     18     28     12     16
# 19  [16, 10751, 12, 14, 0]        8.5        323     19     16  10751     12
#
#     G3  G4 tipo_streaming
# 0    0   0      peliculas
# 1    0   0      peliculas
# 2    0   0      peliculas
# 3    0   0      peliculas
# 4    0   0      peliculas
# 5    0   0      peliculas
# 6    0   0      peliculas
# 7    0   0      peliculas
# 8    0   0      peliculas
# 9    0   0      peliculas
# 10  53   0      peliculas
# 11   0   0      peliculas
# 12   0   0      peliculas
# 13   0   0      peliculas
# 14   0   0      peliculas
# 15   0   0      peliculas
# 16   0   0      peliculas
# 17   0   0      peliculas
# 18  18   0      peliculas
# 19  14   0      peliculas

# %%
############################################################################################################################

# %%
##insert series##
url='https://api.themoviedb.org/3/tv/top_rated?api_key=76f3ff736cde9a95c8dde41456f28cda&language=en-US&page={}'
    
response = requests.get(url)
if response.status_code==200:
      
            series = pd.DataFrame(response.json()["results"])[['id','name','first_air_date','genre_ids','vote_average','vote_count']]
        
        
for i in range(1, 4):
             response = requests.get(url)
             temp_df = pd.DataFrame(response.json()["results"])[['id','name','first_air_date','genre_ids','vote_average','vote_count']]
             series.append(temp_df, ignore_index=False)
        
        
            # print(series) ##Visualizo los datos
# Out:
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\4028453502.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   series.append(temp_df, ignore_index=False)
#         id                              name first_air_date  \
# 0     1396                      Breaking Bad     2008-01-20
# 1    94605                            Arcane     2021-11-06
# 2   100088                    The Last of Us     2023-01-15
# 3    60625                    Rick and Morty     2013-12-02
# 4    37854                         One Piece     1999-10-20
# 5    31911  Fullmetal Alchemist: Brotherhood     2009-04-05
# 6    70785                    Anne with an E     2017-03-19
# 7    85937    Demon Slayer: Kimetsu no Yaiba     2019-04-06
# 8    67915                            Goblin     2016-12-02
# 9    65930                  My Hero Academia     2016-04-03
# 10   95557                        Invincible     2021-03-25
# 11   92685                     The Owl House     2020-01-10
# 12     246        Avatar: The Last Airbender     2005-02-21
# 13   31132                      Regular Show     2010-09-06
# 14  114410                      Chainsaw Man     2022-10-12
# 15   83121          Kaguya-sama: Love Is War     2019-01-12
# 16  135157                  Alchemy of Souls     2022-06-18
# 17   89456                            Primal     2019-10-08
# 18   46298                   Hunter x Hunter     2011-10-02
# 19  213762  Be Eternal: Champions of America     2022-11-03
#
#                      genre_ids  vote_average  vote_count
# 0                     [18, 80]           8.9       11690
# 1       [16, 10765, 10759, 18]           8.8        3061
# 2                         [18]           8.7        3485
# 3       [16, 35, 10765, 10759]           8.7        8204
# 4              [10759, 35, 16]           8.7        3733
# 5           [10759, 16, 10765]           8.7        1630
# 6                  [18, 10751]           8.7        4254
# 7           [16, 10759, 10765]           8.7        5199
# 8              [18, 10765, 35]           8.7        2469
# 9                  [10759, 16]           8.7        4327
# 10      [16, 10765, 10759, 18]           8.7        3480
# 11  [16, 10765, 18, 10759, 35]           8.7        1300
# 12          [16, 10759, 10765]           8.7        3280
# 13                    [16, 35]           8.7        1688
# 14      [16, 10759, 10765, 35]           8.7        1049
# 15                [16, 35, 18]           8.7         612
# 16    [18, 10759, 9648, 10765]           8.7         349
# 17             [10759, 16, 18]           8.7        1182
# 18             [10759, 16, 18]           8.7        1374
# 19                        [99]           8.7         111
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\4028453502.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   series.append(temp_df, ignore_index=False)
#         id                              name first_air_date  \
# 0     1396                      Breaking Bad     2008-01-20
# 1    94605                            Arcane     2021-11-06
# 2   100088                    The Last of Us     2023-01-15
# 3    60625                    Rick and Morty     2013-12-02
# 4    37854                         One Piece     1999-10-20
# 5    31911  Fullmetal Alchemist: Brotherhood     2009-04-05
# 6    70785                    Anne with an E     2017-03-19
# 7    85937    Demon Slayer: Kimetsu no Yaiba     2019-04-06
# 8    67915                            Goblin     2016-12-02
# 9    65930                  My Hero Academia     2016-04-03
# 10   95557                        Invincible     2021-03-25
# 11   92685                     The Owl House     2020-01-10
# 12     246        Avatar: The Last Airbender     2005-02-21
# 13   31132                      Regular Show     2010-09-06
# 14  114410                      Chainsaw Man     2022-10-12
# 15   83121          Kaguya-sama: Love Is War     2019-01-12
# 16  135157                  Alchemy of Souls     2022-06-18
# 17   89456                            Primal     2019-10-08
# 18   46298                   Hunter x Hunter     2011-10-02
# 19  213762  Be Eternal: Champions of America     2022-11-03
#
#                      genre_ids  vote_average  vote_count
# 0                     [18, 80]           8.9       11690
# 1       [16, 10765, 10759, 18]           8.8        3061
# 2                         [18]           8.7        3485
# 3       [16, 35, 10765, 10759]           8.7        8204
# 4              [10759, 35, 16]           8.7        3733
# 5           [10759, 16, 10765]           8.7        1630
# 6                  [18, 10751]           8.7        4254
# 7           [16, 10759, 10765]           8.7        5199
# 8              [18, 10765, 35]           8.7        2469
# 9                  [10759, 16]           8.7        4327
# 10      [16, 10765, 10759, 18]           8.7        3480
# 11  [16, 10765, 18, 10759, 35]           8.7        1300
# 12          [16, 10759, 10765]           8.7        3280
# 13                    [16, 35]           8.7        1688
# 14      [16, 10759, 10765, 35]           8.7        1049
# 15                [16, 35, 18]           8.7         612
# 16    [18, 10759, 9648, 10765]           8.7         349
# 17             [10759, 16, 18]           8.7        1182
# 18             [10759, 16, 18]           8.7        1374
# 19                        [99]           8.7         111
#         id                              name first_air_date  \
# 0     1396                      Breaking Bad     2008-01-20
# 1    94605                            Arcane     2021-11-06
# 2   100088                    The Last of Us     2023-01-15
# 3    60625                    Rick and Morty     2013-12-02
# 4    37854                         One Piece     1999-10-20
# 5    31911  Fullmetal Alchemist: Brotherhood     2009-04-05
# 6    70785                    Anne with an E     2017-03-19
# 7    85937    Demon Slayer: Kimetsu no Yaiba     2019-04-06
# 8    67915                            Goblin     2016-12-02
# 9    65930                  My Hero Academia     2016-04-03
# 10   95557                        Invincible     2021-03-25
# 11   92685                     The Owl House     2020-01-10
# 12     246        Avatar: The Last Airbender     2005-02-21
# 13   31132                      Regular Show     2010-09-06
# 14  114410                      Chainsaw Man     2022-10-12
# 15   83121          Kaguya-sama: Love Is War     2019-01-12
# 16  135157                  Alchemy of Souls     2022-06-18
# 17   89456                            Primal     2019-10-08
# 18   46298                   Hunter x Hunter     2011-10-02
# 19  213762  Be Eternal: Champions of America     2022-11-03
#
#                      genre_ids  vote_average  vote_count
# 0                     [18, 80]           8.9       11690
# 1       [16, 10765, 10759, 18]           8.8        3061
# 2                         [18]           8.7        3485
# 3       [16, 35, 10765, 10759]           8.7        8204
# 4              [10759, 35, 16]           8.7        3733
# 5           [10759, 16, 10765]           8.7        1630
# 6                  [18, 10751]           8.7        4254
# 7           [16, 10759, 10765]           8.7        5199
# 8              [18, 10765, 35]           8.7        2469
# 9                  [10759, 16]           8.7        4327
# 10      [16, 10765, 10759, 18]           8.7        3480
# 11  [16, 10765, 18, 10759, 35]           8.7        1300
# 12          [16, 10759, 10765]           8.7        3280
# 13                    [16, 35]           8.7        1688
# 14      [16, 10759, 10765, 35]           8.7        1049
# 15                [16, 35, 18]           8.7         612
# 16    [18, 10759, 9648, 10765]           8.7         349
# 17             [10759, 16, 18]           8.7        1182
# 18             [10759, 16, 18]           8.7        1374
# 19                        [99]           8.7         111
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\4028453502.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   series.append(temp_df, ignore_index=False)

# %%
##convierto el campo genre_ids a lista y completo el largo de la sublista##
genre_id=series['genre_ids'].tolist()

tamanio=len (genre_id)
for i in range(tamanio):
    longitud = len(genre_id[i])
   # print(longitud)
    while longitud<5:
        genre_id[i].append(0)
       # print(genre_ids[i])
        longitud+=1
    #print(longitud)

#print(genre_id)

# %%
#convierto la lista genre_ids a dataframe##
df_genre_id = pd.DataFrame(genre_ids)
#convierto el index como columna
df_genre_id['index'] = df_genre_id.index
#print(df_genre_id)

# %%
#convierto el index como columna del df series
series['index'] = series.index

# %%
#Uno df series con df df_genre_id por el index
series_tv=pd.merge(series,df_genre_ids,on='index',how='left')
#series_tv

# %%
## renombro columnas en df series##
series_tv.rename(columns = {'name':'nombre','first_air_date':'fecha_lanzamiento','genre_ids':'id_genero','vote_average':'voto_prom','vote_count':'voto_cant',0:'G0',1:'G1',2:'G2',3:'G3',4:'G4'}, inplace = True)

#creo y completo la columna tipo_streaming
series_tv["tipo_streaming"] = np.nan
series_tv["tipo_streaming"].fillna("series", inplace = True)
series_tv
# Out:
#         id                            nombre fecha_lanzamiento  \
# 0     1396                      Breaking Bad        2008-01-20
# 1    94605                            Arcane        2021-11-06
# 2   100088                    The Last of Us        2023-01-15
# 3    60625                    Rick and Morty        2013-12-02
# 4    37854                         One Piece        1999-10-20
# 5    31911  Fullmetal Alchemist: Brotherhood        2009-04-05
# 6    70785                    Anne with an E        2017-03-19
# 7    85937    Demon Slayer: Kimetsu no Yaiba        2019-04-06
# 8    67915                            Goblin        2016-12-02
# 9    65930                  My Hero Academia        2016-04-03
# 10   95557                        Invincible        2021-03-25
# 11   92685                     The Owl House        2020-01-10
# 12     246        Avatar: The Last Airbender        2005-02-21
# 13   31132                      Regular Show        2010-09-06
# 14  114410                      Chainsaw Man        2022-10-12
# 15   83121          Kaguya-sama: Love Is War        2019-01-12
# 16  135157                  Alchemy of Souls        2022-06-18
# 17   89456                            Primal        2019-10-08
# 18   46298                   Hunter x Hunter        2011-10-02
# 19  213762  Be Eternal: Champions of America        2022-11-03
#
#                       id_genero  voto_prom  voto_cant  index     G0     G1  \
# 0             [18, 80, 0, 0, 0]        8.9      11690      0     18     80
# 1     [16, 10765, 10759, 18, 0]        8.8       3061      1     18     80
# 2              [18, 0, 0, 0, 0]        8.7       3485      2     35     14
# 3     [16, 35, 10765, 10759, 0]        8.7       8204      3     18     80
# 4         [10759, 35, 16, 0, 0]        8.7       3733      4     35     18
# 5      [10759, 16, 10765, 0, 0]        8.7       1630      5     18     36
# 6          [18, 10751, 0, 0, 0]        8.7       4254      6     16  10751
# 7      [16, 10759, 10765, 0, 0]        8.7       5199      7     18      0
# 8         [18, 10765, 35, 0, 0]        8.7       2469      8  10749     16
# 9          [10759, 16, 0, 0, 0]        8.7       4327      9     35     53
# 10    [16, 10765, 10759, 18, 0]        8.7       3480     10     18     28
# 11   [16, 10765, 18, 10759, 35]        8.7       1300     11     14     18
# 12     [16, 10759, 10765, 0, 0]        8.7       3280     12     53     80
# 13            [16, 35, 0, 0, 0]        8.7       1688     13     37      0
# 14    [16, 10759, 10765, 35, 0]        8.7       1049     14     35     18
# 15           [16, 35, 18, 0, 0]        8.7        612     15  10749     16
# 16  [18, 10759, 9648, 10765, 0]        8.7        349     16     12     14
# 17        [10759, 16, 18, 0, 0]        8.7       1182     17     18     80
# 18        [10759, 16, 18, 0, 0]        8.7       1374     18     28     12
# 19             [99, 0, 0, 0, 0]        8.7        111     19     16  10751
#
#        G2  G3  G4 tipo_streaming
# 0       0   0   0         series
# 1       0   0   0         series
# 2       0   0   0         series
# 3       0   0   0         series
# 4   10749   0   0         series
# 5   10752   0   0         series
# 6      14   0   0         series
# 7       0   0   0         series
# 8      18   0   0         series
# 9      18   0   0         series
# 10     80  53   0         series
# 11     80   0   0         series
# 12      0   0   0         series
# 13      0   0   0         series
# 14  10749   0   0         series
# 15      0   0   0         series
# 16     28   0   0         series
# 17      0   0   0         series
# 18     16  18   0         series
# 19     12  14   0         series

# %%
####################################################################################################

# %%
## uno los dataframe ##
df_streaming=pd.concat([peliculas,series_tv], ignore_index=True)

#print(df_streaming)

# %%
###insert  un DF de generos
url='https://api.themoviedb.org/3/genre/movie/list?api_key=76f3ff736cde9a95c8dde41456f28cda&language=en-US'
response = requests.get(url)
if response.status_code==200:
      
            generos = pd.DataFrame(response.json()["genres"])[['id','name']]
        
        
for i in range(1, 4):
             response = requests.get(url)
             temp_df = pd.DataFrame(response.json()["genres"])[['id','name']]
             generos.append(temp_df, ignore_index=False)
        
        
             #print(generos) ##Visualizo los datos
# Out:
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\2710919535.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   generos.append(temp_df, ignore_index=False)
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\2710919535.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   generos.append(temp_df, ignore_index=False)
# C:\Users\Adriana Prieto\AppData\Local\Temp\ipykernel_47536\2710919535.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   generos.append(temp_df, ignore_index=False)

# %%
## Modifico ID y nombre de DF generos para cruzarlo con cada id generos de DF df_streaming
G0=generos.copy()
G0.rename(columns = {'id':'G0','name':'name0'}, inplace = True)

G1=generos.copy()
G1.rename(columns = {'id':'G1','name':'name1'}, inplace = True)

G2=generos.copy()
G2.rename(columns = {'id':'G2','name':'name2'}, inplace = True)

G3=generos.copy()
G3.rename(columns = {'id':'G3','name':'name3'}, inplace = True)

G4=generos.copy()
G4.rename(columns = {'id':'G4','name':'name4'}, inplace = True)

# %%
###Cruzo df  df_streaming con el DF detalle de generos
df_streaming=pd.merge(df_streaming,G0,on='G0',how='left')
df_streaming=pd.merge(df_streaming,G1,on='G1',how='left')
df_streaming=pd.merge(df_streaming,G2,on='G2',how='left')
df_streaming=pd.merge(df_streaming,G3,on='G3',how='left')
df_streaming=pd.merge(df_streaming,G4,on='G4',how='left')
#df_streaming

# %%
## Reemplazo los nulls con espacios
df_streaming['name1'].fillna("", inplace = True)
df_streaming['name2'].fillna("", inplace = True)
df_streaming['name3'].fillna("", inplace = True)
df_streaming['name4'].fillna("", inplace = True)

# %%
 #concateno los diferentes campos que tieen un genero
df_streaming['genero'] =pd.DataFrame( np.where(df_streaming['name1']=='' ,df_streaming.name0, df_streaming.name0.str.cat(df_streaming.name1, sep=', ')))
df_streaming['genero'] =pd.DataFrame( np.where(df_streaming['name2']=='' ,df_streaming.genero, df_streaming.genero.str.cat(df_streaming.name2, sep=', ')))
df_streaming['genero'] =pd.DataFrame( np.where(df_streaming['name3']=='' ,df_streaming.genero, df_streaming.genero.str.cat(df_streaming.name3, sep=', ')))
df_streaming['genero'] =pd.DataFrame( np.where(df_streaming['name4']=='' ,df_streaming.genero, df_streaming.genero.str.cat(df_streaming.name4, sep=', ')))
                       
#df_streaming

# %%
## Tomo solo las columnas que me interesa llevar ##
df_streaming=df_streaming.loc[:, ['id','tipo_streaming','nombre','fecha_lanzamiento','genero','voto_prom','voto_cant' ]]

df_streaming
# Out:
#         id tipo_streaming                                         nombre  \
# 0      238      peliculas                                  The Godfather
# 1      278      peliculas                       The Shawshank Redemption
# 2   772071      peliculas                               Cuando Sea Joven
# 3      240      peliculas                          The Godfather Part II
# 4    19404      peliculas                   दिलवाले दुल्हनिया ले जायेंगे
# 5      424      peliculas                               Schindler's List
# 6      129      peliculas                                       千と千尋の神隠し
# 7      389      peliculas                                   12 Angry Men
# 8   372058      peliculas                                          君の名は。
# 9   496243      peliculas                                            기생충
# 10     155      peliculas                                The Dark Knight
# 11     497      peliculas                                 The Green Mile
# 12     680      peliculas                                   Pulp Fiction
# 13     429      peliculas                Il buono, il brutto, il cattivo
# 14      13      peliculas                                   Forrest Gump
# 15  372754      peliculas                                            同級生
# 16     122      peliculas  The Lord of the Rings: The Return of the King
# 17     769      peliculas                                     GoodFellas
# 18  704264      peliculas                      Primal: Tales of Savagery
# 19  995133      peliculas       The Boy, the Mole, the Fox and the Horse
# 20    1396         series                                   Breaking Bad
# 21   94605         series                                         Arcane
# 22  100088         series                                 The Last of Us
# 23   60625         series                                 Rick and Morty
# 24   37854         series                                      One Piece
# 25   31911         series               Fullmetal Alchemist: Brotherhood
# 26   70785         series                                 Anne with an E
# 27   85937         series                 Demon Slayer: Kimetsu no Yaiba
# 28   67915         series                                         Goblin
# 29   65930         series                               My Hero Academia
# 30   95557         series                                     Invincible
# 31   92685         series                                  The Owl House
# 32     246         series                     Avatar: The Last Airbender
# 33   31132         series                                   Regular Show
# 34  114410         series                                   Chainsaw Man
# 35   83121         series                       Kaguya-sama: Love Is War
# 36  135157         series                               Alchemy of Souls
# 37   89456         series                                         Primal
# 38   46298         series                                Hunter x Hunter
# 39  213762         series               Be Eternal: Champions of America
#
#    fecha_lanzamiento                                 genero  voto_prom  \
# 0         1972-03-14                           Drama, Crime        8.7
# 1         1994-09-23                           Drama, Crime        8.7
# 2         2022-09-14                        Comedy, Fantasy        8.6
# 3         1974-12-20                           Drama, Crime        8.6
# 4         1995-10-19                 Comedy, Drama, Romance        8.6
# 5         1993-12-15                    Drama, History, War        8.6
# 6         2001-07-20             Animation, Family, Fantasy        8.5
# 7         1957-04-10                                  Drama        8.5
# 8         2016-08-26              Romance, Animation, Drama        8.5
# 9         2019-05-30                Comedy, Thriller, Drama        8.5
# 10        2008-07-14         Drama, Action, Crime, Thriller        8.5
# 11        1999-12-10                  Fantasy, Drama, Crime        8.5
# 12        1994-09-10                        Thriller, Crime        8.5
# 13        1966-12-23                                Western        8.5
# 14        1994-06-23                 Comedy, Drama, Romance        8.5
# 15        2016-02-20                     Romance, Animation        8.5
# 16        2003-12-01             Adventure, Fantasy, Action        8.5
# 17        1990-09-12                           Drama, Crime        8.5
# 18        2019-11-21    Action, Adventure, Animation, Drama        8.5
# 19        2022-12-25  Animation, Family, Adventure, Fantasy        8.5
# 20        2008-01-20                           Drama, Crime        8.9
# 21        2021-11-06                           Drama, Crime        8.8
# 22        2023-01-15                        Comedy, Fantasy        8.7
# 23        2013-12-02                           Drama, Crime        8.7
# 24        1999-10-20                 Comedy, Drama, Romance        8.7
# 25        2009-04-05                    Drama, History, War        8.7
# 26        2017-03-19             Animation, Family, Fantasy        8.7
# 27        2019-04-06                                  Drama        8.7
# 28        2016-12-02              Romance, Animation, Drama        8.7
# 29        2016-04-03                Comedy, Thriller, Drama        8.7
# 30        2021-03-25         Drama, Action, Crime, Thriller        8.7
# 31        2020-01-10                  Fantasy, Drama, Crime        8.7
# 32        2005-02-21                        Thriller, Crime        8.7
# 33        2010-09-06                                Western        8.7
# 34        2022-10-12                 Comedy, Drama, Romance        8.7
# 35        2019-01-12                     Romance, Animation        8.7
# 36        2022-06-18             Adventure, Fantasy, Action        8.7
# 37        2019-10-08                           Drama, Crime        8.7
# 38        2011-10-02    Action, Adventure, Animation, Drama        8.7
# 39        2022-11-03  Animation, Family, Adventure, Fantasy        8.7
#
#     voto_cant
# 0       17944
# 1       23783
# 2         226
# 3       10831
# 4        4131
# 5       14068
# 6       14302
# 7        7273
# 8        9840
# 9       15734
# 10      29719
# 11      15406
# 12      25179
# 13       7396
# 14      24664
# 15        304
# 16      21594
# 17      11256
# 18        263
# 19        323
# 20      11690
# 21       3061
# 22       3485
# 23       8204
# 24       3733
# 25       1630
# 26       4254
# 27       5199
# 28       2469
# 29       4327
# 30       3480
# 31       1300
# 32       3280
# 33       1688
# 34       1049
# 35        612
# 36        349
# 37       1182
# 38       1374
# 39        111

# %%
###Conexion Redshift###
url="data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws"
data_base="data-engineer-database"
user="marce200452_coderhouse"
#with open("C:/Users/Windows/Downloads/pwd_coder.txt",'r') as f:
pwd="2NA8hfK5c3" #f.read()

try:
    conn = psycopg2.connect(
        host='data-engineer-cluster.cyhh5bfevlmn.us-east-1.redshift.amazonaws.com',
        dbname=data_base,
        user=user,
        password=pwd,
        port='5439'
    )
    print("Connected to Redshift successfully!")
    
except Exception as e:
    print("Unable to connect to Redshift.")
    print(e)
# Out:
# Connected to Redshift successfully!

# %%
df_streaming.dtypes
# Out:
# id                     int64
# tipo_streaming        object
# nombre                object
# fecha_lanzamiento     object
# genero                object
# voto_prom            float64
# voto_cant              int64
# dtype: object

# %%
###Insertar Datos##
def cargar_en_redshift(conn, table_name, dataframe):
    dtypes= df_streaming.dtypes
    df_streaming.dtypes
    cols= list(dtypes.index )
    tipos= list(dtypes.values)
    type_map = {'int64': 'INT','object': 'VARCHAR(500)','object': 'VARCHAR(100)','object': 'VARCHAR(100)','object': 'VARCHAR(100)','float64': 'Decimal(10,2)','int64': 'INT'}
    sql_dtypes = [type_map[str(dtype)] for dtype in tipos]
       
       # Combine column definitions into the CREATE TABLE statement
    column_defs = [f"{name} {data_type}" for name, data_type in zip(cols, sql_dtypes)]
    table_schema = f"""
             CREATE TABLE IF NOT EXISTS {table_name} (
                 {', '.join(column_defs)}
            );
            """
        #print(table_schema)
#Crear la tabla
    cur = conn.cursor()
    cur.execute(table_schema)
#     # Generar los valores a insertar
    values = [tuple(x) for x in df_streaming.to_numpy()]
# Definir el INSERT
    insert_sql = f"INSERT INTO {table_name} ({', '.join(cols)}) VALUES %s"
        
      
     # Execute the transaction to insert the data
    cur.execute("BEGIN")
    execute_values(cur, insert_sql, values)
    cur.execute("COMMIT")
    print('Proceso terminado')

# %%
    
    ## Llama funcion cargar datos ##
    cargar_en_redshift(conn=conn, table_name='streaming_videos', dataframe=df_streaming)
# Out:
# Proceso terminado
